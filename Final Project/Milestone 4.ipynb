# %%
import requests
import pandas as pd
import json
from pandas.io.json import json_normalize
import warnings
warnings.filterwarnings('ignore')
print("Enter a Pokemon!")
print("Example Pokemon to choose from: krabby, charizard, diglett, zubat")
pokemon = input('Pokemon:')
response_certain_pokemon = requests.get("https://pokeapi.co/api/v2/pokemon/" + pokemon).json()
# Out:
# Enter a Pokemon!
# Example Pokemon to choose from: krabby, charizard, diglett, zubat
# Pokemon:poliwrath

# %%
print(response_certain_pokemon)
# Out:
# {'abilities': [{'ability': {'name': 'swift-swim', 'url': 'https://pokeapi.co/api/v2/ability/33/'}, 'is_hidden': True, 'slot': 3}, {'ability': {'name': 'damp', 'url': 'https://pokeapi.co/api/v2/ability/6/'}, 'is_hidden': False, 'slot': 2}, {'ability': {'name': 'water-absorb', 'url': 'https://pokeapi.co/api/v2/ability/11/'}, 'is_hidden': False, 'slot': 1}], 'base_experience': 230, 'forms': [{'name': 'poliwrath', 'url': 'https://pokeapi.co/api/v2/pokemon-form/62/'}], 'game_indices': [{'game_index': 62, 'version': {'name': 'white-2', 'url': 'https://pokeapi.co/api/v2/version/22/'}}, {'game_index': 62, 'version': {'name': 'black-2', 'url': 'https://pokeapi.co/api/v2/version/21/'}}, {'game_index': 62, 'version': {'name': 'white', 'url': 'https://pokeapi.co/api/v2/version/18/'}}, {'game_index': 62, 'version': {'name': 'black', 'url': 'https://pokeapi.co/api/v2/version/17/'}}, {'game_index': 62, 'version': {'name': 'soulsilver', 'url': 'https://pokeapi.co/api/v2/version/16/'}}, {'game_index'
# ...

# %%
df = pd.DataFrame.from_dict(json_normalize(response_certain_pokemon), orient="columns")
df.head()
# Out:
#                                            abilities  base_experience  \
# 0  [{'ability': {'name': 'swift-swim', 'url': 'ht...              230
#
#                                                forms  \
# 0  [{'name': 'poliwrath', 'url': 'https://pokeapi...
#
#                                         game_indices  height  \
# 0  [{'game_index': 62, 'version': {'name': 'white...      13
#
#                                           held_items  id  is_default  \
# 0  [{'item': {'name': 'kings-rock', 'url': 'https...  62        True
#
#                           location_area_encounters  \
# 0  https://pokeapi.co/api/v2/pokemon/62/encounters
#
#                                                moves  ... species.name  \
# 0  [{'move': {'name': 'double-slap', 'url': 'http...  ...    poliwrath
#
#                                      species.url  \
# 0  https://pokeapi.co/api/v2/pokemon-species/62/
#
#                                 sprites.back_default sprites.back_female  \
# ...

# %%
# Change column heirarchy - moves
length_types = len(df['types'][0])
i_types = 0

while i_types < length_types:
    del df['types'][0][i_types]['slot']
    del df['types'][0][i_types]['type']['url']
    i_types +=1
    
df['types'][0] = ' '.join([str(elem) for elem in df['types'][0]])
df['types'][0] = (df['types'][0]).replace("{'type': {'name': '", "")
df['types'][0] = (df['types'][0]).replace("'", "")
print(df['types'][0])
# Out:
# fighting}} water}}

# %%
# Split types to account for second types
#if "}}" in df['types'][0]:
df['types'][0] = (df['types'][0]).replace("}}", "")
if " " in df['types'][0]:
    df[['type1', 'type2']] = df.types.str.split(" ",expand=True)
else:
    print(df['types'][0])
# Fill in empty values of secondary type with 'No Secondary Type'
    df['types'][0] = (df['types'][0])+"PokemonNo Secondary Type"
    print(df['types'][0])
    df[['type1', 'type2']] = df.types.str.split("Pokemon",expand=True)

df.head()
# Out:
#                                            abilities  base_experience  \
# 0  [{'ability': {'name': 'swift-swim', 'url': 'ht...              230
#
#                                                forms  \
# 0  [{'name': 'poliwrath', 'url': 'https://pokeapi...
#
#                                         game_indices  height  \
# 0  [{'game_index': 62, 'version': {'name': 'white...      13
#
#                                           held_items  id  is_default  \
# 0  [{'item': {'name': 'kings-rock', 'url': 'https...  62        True
#
#                           location_area_encounters  \
# 0  https://pokeapi.co/api/v2/pokemon/62/encounters
#
#                                                moves  ...  \
# 0  [{'move': {'name': 'double-slap', 'url': 'http...  ...
#
#                                 sprites.back_default  sprites.back_female  \
# 0  https://raw.githubusercontent.com/PokeAPI/spri...                 None
#
#                                   sprites.back_shiny  \
# ...

# %%
# Fill in empty values of secondary type with 'No Secondary Type'
df.head()
# Out:
#                                            abilities  base_experience  \
# 0  [{'ability': {'name': 'swift-swim', 'url': 'ht...              230
#
#                                                forms  \
# 0  [{'name': 'poliwrath', 'url': 'https://pokeapi...
#
#                                         game_indices  height  \
# 0  [{'game_index': 62, 'version': {'name': 'white...      13
#
#                                           held_items  id  is_default  \
# 0  [{'item': {'name': 'kings-rock', 'url': 'https...  62        True
#
#                           location_area_encounters  \
# 0  https://pokeapi.co/api/v2/pokemon/62/encounters
#
#                                                moves  ...  \
# 0  [{'move': {'name': 'double-slap', 'url': 'http...  ...
#
#                                 sprites.back_default  sprites.back_female  \
# 0  https://raw.githubusercontent.com/PokeAPI/spri...                 None
#
#                                   sprites.back_shiny  \
# ...

# %%
# Removed unnecessary fields unrelated to pokemon characterists
df.drop(['stats','types','forms','location_area_encounters','order','sprites.back_default', 'sprites.back_female', 'sprites.back_shiny', 'sprites.back_shiny_female', 'sprites.front_default', 'sprites.front_female', 'sprites.front_shiny', 'sprites.front_shiny_female', 'species.name', 'species.url', 'held_items', 'is_default'], axis=1, inplace=True)
df.head()
# Out:
#                                            abilities  base_experience  \
# 0  [{'ability': {'name': 'swift-swim', 'url': 'ht...              230
#
#                                         game_indices  height  id  \
# 0  [{'game_index': 62, 'version': {'name': 'white...      13  62
#
#                                                moves       name  weight  \
# 0  [{'move': {'name': 'double-slap', 'url': 'http...  poliwrath     540
#
#       type1  type2
# 0  fighting  water

# %%
# Readable Format
df = df[['id','name','type1','type2','base_experience','abilities', 'moves']]
df.head()
# Out:
#    id       name     type1  type2  base_experience  \
# 0  62  poliwrath  fighting  water              230
#
#                                            abilities  \
# 0  [{'ability': {'name': 'swift-swim', 'url': 'ht...
#
#                                                moves
# 0  [{'move': {'name': 'double-slap', 'url': 'http...

# %%
# Replace Headers
df = df.rename(columns={'id': 'pokedex_number'})
df.head()
# Out:
#    pokedex_number       name     type1  type2  base_experience  \
# 0              62  poliwrath  fighting  water              230
#
#                                            abilities  \
# 0  [{'ability': {'name': 'swift-swim', 'url': 'ht...
#
#                                                moves
# 0  [{'move': {'name': 'double-slap', 'url': 'http...

# %%
# Change column heirarchy - abilities
length_abilities = len(df['abilities'][0])
i_abilities = 0

while i_abilities < length_abilities:
    del df['abilities'][0][i_abilities]['is_hidden']
    del df['abilities'][0][i_abilities]['slot']
    del df['abilities'][0][i_abilities]['ability']['url']
    i_abilities +=1
    
df['abilities'][0] = ' '.join([str(elem) for elem in df['abilities'][0]])
df['abilities'][0] = (df['abilities'][0]).replace("{'ability': {'name': '", "")
df['abilities'][0] = (df['abilities'][0]).replace("'}}", "")
df['abilities'][0] = list(df['abilities'][0].split(" "))
print(df['abilities'][0])
# Out:
# ['swift-swim', 'damp', 'water-absorb']

# %%
# Change column heirarchy - moves
length_moves = len(df['moves'][0])
i_moves = 0

while i_moves < length_moves:
    del df['moves'][0][i_moves]['version_group_details']
    del df['moves'][0][i_moves]['move']['url']
    i_moves +=1
    
df['moves'][0] = ' '.join([str(elem) for elem in df['moves'][0]])
df['moves'][0] = (df['moves'][0]).replace("{'move': {'name': '", "")
df['moves'][0] = (df['moves'][0]).replace("'}}", "")
df['moves'][0] = list(df['moves'][0].split(" "))
print(df['moves'][0])
# Out:
# ['double-slap', 'mega-punch', 'ice-punch', 'mega-kick', 'headbutt', 'body-slam', 'take-down', 'double-edge', 'water-gun', 'surf', 'ice-beam', 'blizzard', 'bubble-beam', 'hyper-beam', 'submission', 'counter', 'seismic-toss', 'strength', 'earthquake', 'fissure', 'dig', 'toxic', 'psychic', 'hypnosis', 'rage', 'mimic', 'double-team', 'defense-curl', 'bide', 'metronome', 'waterfall', 'skull-bash', 'psywave', 'rest', 'rock-slide', 'substitute', 'thief', 'mind-reader', 'snore', 'curse', 'protect', 'mud-slap', 'icy-wind', 'detect', 'endure', 'swagger', 'attract', 'sleep-talk', 'return', 'frustration', 'dynamic-punch', 'hidden-power', 'rain-dance', 'rock-smash', 'whirlpool', 'hail', 'facade', 'focus-punch', 'helping-hand', 'brick-break', 'endeavor', 'secret-power', 'dive', 'rock-tomb', 'bulk-up', 'water-pulse', 'natural-gift', 'payback', 'fling', 'poison-jab', 'vacuum-wave', 'focus-blast', 'giga-impact', 'rock-climb', 'captivate', 'low-sweep', 'round', 'scald', 'circle-throw', 'bulldoze', 'wo
# ...

# %%
df.head()
# Out:
#    pokedex_number       name     type1  type2  base_experience  \
# 0              62  poliwrath  fighting  water              230
#
#                           abilities  \
# 0  [swift-swim, damp, water-absorb]
#
#                                                moves
# 0  [double-slap, mega-punch, ice-punch, mega-kick...

# %%
df.to_csv(r'C:\Users\Gabe\Documents\Bellevue University\Data Preparation\Final Project\Data for Pokemon Database\PokemonAPI.csv', index = False)
